# %% [markdown]
# ___
#
# # Visualización de datos con Pandas - Ejercicios
#
# Este es un ejercicio sencillo para revisar las diversas gráficas presentadas anteriormente.

# %% [markdown]
# # Sección nueva

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('https://drive.google.com/file/d/1v4bwt_TZzVrVcJx0dciyLPAOjFbSaJDe/view?usp=sharing')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Columns: 279 entries, <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style>@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic') to [0]
# dtypes: float64(76), object(203)
# memory usage: 392.5+ KB

# %%
df = pd.read_csv('df3.csv')
df.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# **Recrear esta gráfica de dispersión de b vs a. Tenga en cuenta el color y el tamaño de los puntos. También tenga en cuenta el tamaño de la figura.**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
plt.style.use('ggplot')
df.plot(kind='scatter', x='a',y='b', figsize=(12,3), color= 'r', s=50)

# %%
# NO USAR ESTA CELDA

# %% [markdown]
# **Cree un histograma de la columna 'a'.**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
plt.style.use('default')
df['a'].plot(kind='hist',figsize=(4.3,2.8), fontsize= 7)
plt.ylabel('Frequency', size=10)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# NO USAR ESTA CELDA

# %% [markdown]
# **Use la hoja de estilos 'ggplot' y repita el histograma. También, añada más intervalos al histograma, y tenga en cuenta su nivel de transparencia para que quede como el que se presenta a continuación.**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
df['a'].plot(kind='hist', figsize=(6,4.2), bins=25, alpha=0.5)
plt.ylabel('Frequency', size=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# NO USAR ESTA CELDA

# %% [markdown]
# **Cree un boxplot (diagrama de caja) para comparar únicamente las columnas a y b.**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
df.boxplot(column=['a', 'b'])

# %%
# NO USAR ESTA CELDA

# %% [markdown]
# **Crear un gráfico de línea para la columna 'd'**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
plt.style.use('ggplot')
df['d'].plot(kind='line', figsize=(6,4))
plt.xlim(0, 500)
# Out:
# (0.0, 500.0)

# %%
# NO USAR ESTA CELDA

# %% [markdown]
# **Modifique los parámetros necesarios para cambiar el tamaño, ancho de línea y el estilo de la trama (guiones).**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

df['d'].plot(kind='line', figsize=(15,3), linewidth=0.8, ls='--')
plt.xlim(0, 500)
# Out:
# (0.0, 500.0)

# %%
# NO USAR ESTA CELDA

# %% [markdown]
# **Crear un gráfico de área de todas las columnas pero sólo para las filas desde la 0 hasta la número 30. (Pista: use .iloc).**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
plt.style.use('ggplot')
df.iloc[0:31,0:31].plot(kind='area', figsize=(4,2.8), fontsize=9.5, alpha=0.4)
plt.xlim(0, 29)
plt.legend(loc='upper right', fontsize= 8)
plt.show()

# %%
# NO USAR ESTA CELDA

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
plt.style.use('ggplot')
df.iloc[0:31,0:31].plot(kind='area', figsize=(6,4), fontsize=9.5, alpha=0.4)
plt.xlim(0, 29)
plt.ylim(0.0, 2.8)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize= 10)
plt.show()

# %%
# NO USAR ESTA CELDA
